# %% [markdown]
# <a href="https://colab.research.google.com/github/hrbae/DRB_ML_Training/blob/main/8th_Day/Entropy_and_Loss_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pylab as plt


def f(x):
    return -np.log(x)    

X = np.arange(0.0, 1.0, 0.00001)
Y = f(X)
plt.plot(X, Y)
plt.ylim(-0.1, 10.1)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in log

# %%
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import numpy as np

# Function compute Entropy
def H(p):
    #####################################################################
    # TODO:                                                             #
    # Compute the Entropy of random variable X with 0*log0 = 0          #
    #####################################################################
    id_p = np.where(p != 0)
    return -np.sum(p[id_p]*np.log(p[id_p]))
    #####################################################################
    #                       END OF YOUR CODE                            #
    #####################################################################
    

# Initialize
theta = np.arange(0, 1, 0.01)
#p = np.array([1-theta, theta/4, theta/4, theta/4, theta/4]).T
p = np.array([1-theta, theta]).T
print(p)
# Visualize
HX = []
id_max = 0
H_max = 0
for i in range(len(theta)):
    temp = H(p[i])
    HX.append(temp)
    if (temp > H_max):
        H_max = temp
        id_max = i

plt.plot(p[:,1], HX)
plt.plot(p[id_max,1], H_max, 'ro')
# Out:
# [[1.   0.  ]
#  [0.99 0.01]
#  [0.98 0.02]
#  [0.97 0.03]
#  [0.96 0.04]
#  [0.95 0.05]
#  [0.94 0.06]
#  [0.93 0.07]
#  [0.92 0.08]
#  [0.91 0.09]
#  [0.9  0.1 ]
#  [0.89 0.11]
#  [0.88 0.12]
#  [0.87 0.13]
#  [0.86 0.14]
#  [0.85 0.15]
#  [0.84 0.16]
#  [0.83 0.17]
#  [0.82 0.18]
#  [0.81 0.19]
#  [0.8  0.2 ]
#  [0.79 0.21]
#  [0.78 0.22]
#  [0.77 0.23]
#  [0.76 0.24]
#  [0.75 0.25]
#  [0.74 0.26]
#  [0.73 0.27]
#  [0.72 0.28]
#  [0.71 0.29]
#  [0.7  0.3 ]
#  [0.69 0.31]
#  [0.68 0.32]
#  [0.67 0.33]
#  [0.66 0.34]
#  [0.65 0.35]
#  [0.64 0.36]
#  [0.63 0.37]
#  [0.62 0.38]
#  [0.61 0.39]
#  [0.6  0.4 ]
#  [0.59 0.41]
#  [0.58 0.42]
#  [0.57 0.43]
#  [0.56 0.44]
#  [0.55 0.45]
#  [0.54 0.46]
#  [0.53 0.47]
#  [0.52 0.48]
#  [0.51 0.49]
#  [0.5  0.5 ]
#  [0.49 0.51]
#  [0.48 0.52]
#  [0.47 0.53]
#  [0.46 0.54]
#  [0.45 0.55]
#  [0.44 0.56]
#  [0.43 0.57]
#  [0.42 0.58]
#  [0.41 0.59]
#  [0.4  0.6 ]
#  [0.39 0.61]
#  [0.38 0.62]
#  [0.37 0.63]
#  [0.36 0.64]
#  [0.35 0.65]
#  [0.34 0.66]
#  [0.33 0.67]
#  [0.32 0.68]
#  [0.31 0.69]
#  [0.3  0.7 ]
#  [0.29 0.71]
#  [0.28 0.72]
#  [0.27 0.73]
#  [0.26 0.74]
#  [0.25 0.75]
#  [0.24 0.76]
#  [0.23 0.77]
#  [0.22 0.78]
#  [0.21 0.79]
#  [0.2  0.8 ]
#  [0.19 0.81]
#  [0.18 0.82]
#  [0.17 0.83]
#  [0.16 0.84]
#  [0.15 0.85]
#  [0.14 0.86]
#  [0.13 0.87]
#  [0.12 0.88]
#  [0.11 0.89]
#  [0.1  0.9 ]
#  [0.09 0.91]
#  [0.08 0.92]
#  [0.07 0.93]
#  [0.06 0.94]
#  [0.05 0.95]
#  [0.04 0.96]
#  [0.03 0.97]
#  [0.02 0.98]
#  [0.01 0.99]]

# %%
import numpy as np

def H(p, q):
    #############################################################################
    # TODO:                                                                     #
    # Compute the cross-entropy of 2 distributions p, q                         #
    #############################################################################
    return -np.sum(p*np.log(q))
    #############################################################################
    #                               END OF YOUR CODE                            #
    #############################################################################
    # Initialize  

# Function compute Kullback-Leibler divergence
def KLD(p, q):
    #############################################################################
    # TODO:                                                                     #
    # Compute the Kullback-Leibler divergence of 2 disjointed distribution p, q #
    #############################################################################
    return np.sum(p*np.log(p/q))
    #############################################################################
    #                               END OF YOUR CODE                            #
    #############################################################################
    # Initialize
#S = np.array([1,2,3,4,5])
p = np.array([0.1, 0.2, 0.3, 0.3, 0.1])
q = np.array([0.3, 0.3, 0.1, 0.1, 0.2])

#Compute H(p, q)
print("H(p,q)= ", H(p,q))

# Compute D(p||q)
# Expected result: D(p||q) = 0.398898404656
print ("KLD(p||q) = ", KLD(p, q))
print ("KLD(p||q) by defition=", H(p,q)-H(p,p))
# Out:
# H(p,q)=  1.903686688337618
# KLD(p||q) =  0.39889840465642734
# KLD(p||q) by defition= 0.39889840465642723
