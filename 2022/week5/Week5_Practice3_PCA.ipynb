# %% [markdown]
# # 1. Load data

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/hrbae/DRB_ML_Training/main/2022/week5/cereals.csv')
print(df.columns)
# Out:
# Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#        'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#        'rating'],
#       dtype='object')

# %% [markdown]
# # 2. Data Preprocessing

# %%
df = df[['calories', 'protein', 'fat', 'sodium', 'fiber',
       'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
       'rating']]

print(df.columns)
# Out:
# Index(['calories', 'protein', 'fat', 'sodium', 'fiber', 'carbo', 'sugars',
#        'potass', 'vitamins', 'shelf', 'weight', 'cups', 'rating'],
#       dtype='object')

# %%
df
# Out:
#     calories  protein  fat  sodium  fiber  carbo  sugars  potass  vitamins  \
# 0         70        4    1     130   10.0    5.0       6     280        25
# 1        120        3    5      15    2.0    8.0       8     135         0
# 2         70        4    1     260    9.0    7.0       5     320        25
# 3         50        4    0     140   14.0    8.0       0     330        25
# 4        110        2    2     200    1.0   14.0       8      -1        25
# ..       ...      ...  ...     ...    ...    ...     ...     ...       ...
# 72       110        2    1     250    0.0   21.0       3      60        25
# 73       110        1    1     140    0.0   13.0      12      25        25
# 74       100        3    1     230    3.0   17.0       3     115        25
# 75       100        3    1     200    3.0   17.0       3     110        25
# 76       110        2    1     200    1.0   16.0       8      60        25
#
#     shelf  weight  cups     rating
# ...

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
df_scale = scaler.fit_transform(df)
df_scale = pd.DataFrame(df_scale)
df_scale
# Out:
#           0         1         2         3         4         5         6   \
# 0  -1.905397  1.337319 -0.012988 -0.356306  3.314439 -2.257639 -0.208807
# 1   0.677623  0.417912  3.987349 -1.737087 -0.064172 -1.551936  0.244099
# 2  -1.905397  1.337319 -0.012988  1.204578  2.892113 -1.787170 -0.435260
# 3  -2.938605  1.337319 -1.013072 -0.236238  5.003745 -1.551936 -1.567525
# 4   0.161019 -0.501495  0.987096  0.484170 -0.486498 -0.140530  0.244099
# ..       ...       ...       ...       ...       ...       ...       ...
# 72  0.161019 -0.501495 -0.012988  1.084510 -0.908824  1.506111 -0.888166
# 73  0.161019 -1.420902 -0.012988 -0.236238 -0.908824 -0.375764  1.149910
# 74 -0.355585  0.417912 -0.012988  0.844374  0.358155  0.565173 -0.888166
# 75 -0.355585  0.417912 -0.012988  0.484170  0.358155  0.565173 -0.888166
# 76  0.161019 -0.501495 -0.012988  0.484170 -0.486498  0.329939  0.244099
#
#           7        8         9         10        11        12
# ...

# %% [markdown]
# # 3. PCA

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 2)
pca_x = pca.fit_transform(df_scale)
pca.explained_variance_ratio_
# Out:
# array([0.27768061, 0.24142157])

# %%
pca_rlt = pd.DataFrame(pca_x, columns = ['PC1', 'PC2'])
pca_rlt
# Out:
#          PC1       PC2
# 0   5.529765 -1.805980
# 1   0.262997 -1.810757
# 2   4.893527 -2.091762
# 3   7.737473 -0.667950
# 4  -1.146427 -0.215820
# ..       ...       ...
# 72 -0.947976  0.526199
# 73 -2.102265  0.537534
# 74  0.726308  0.599711
# 75  0.449448  1.055519
# 76 -1.082958  0.592464
#
# [77 rows x 2 columns]

# %% [markdown]
# ## Default

# %%
pca = PCA()
pca_x = pca.fit_transform(df_scale)
ratio = pca.explained_variance_ratio_
ratio
# Out:
# array([2.77680611e-01, 2.41421569e-01, 1.39748897e-01, 8.17149838e-02,
#        7.46926381e-02, 5.53198062e-02, 5.16347267e-02, 3.46038126e-02,
#        2.33339532e-02, 1.00530005e-02, 5.62222549e-03, 4.17377643e-03,
#        1.66954050e-17])

# %%
pca_rlt = pd.DataFrame(pca_x, columns = [f'PC{i+1}' for i in range(len(ratio))])
pca_rlt
# Out:
#          PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0   5.529765 -1.805980 -0.613703 -1.131758 -0.875988  0.951639  0.118136
# 1   0.262997 -1.810757 -3.095078  1.846356  2.470918  0.481391  0.650141
# 2   4.893527 -2.091762  0.204152 -1.071774 -1.259489  1.902240 -0.652682
# 3   7.737473 -0.667950  1.172466 -1.404438 -1.373020  0.835324  0.540065
# 4  -1.146427 -0.215820 -0.736076 -0.361809  1.024117  0.409245 -0.995472
# ..       ...       ...       ...       ...       ...       ...       ...
# 72 -0.947976  0.526199  1.153025 -0.273628  0.895087 -0.016599 -1.710099
# 73 -2.102265  0.537534 -1.362032 -0.601460 -0.276307 -0.161588  0.359935
# 74  0.726308  0.599711  0.900750  0.948357 -0.880354  0.678708 -0.798526
# 75  0.449448  1.055519  0.984321  1.194254 -0.635025  0.621373  0.306092
# 76 -1.082958  0.592464 -0.194723  0.495844 -0.921950  0.241289 -0.543713
#
#          PC8       PC9      PC10      PC11      PC12          PC13
# ...

# %%
df_ratio = pd.DataFrame(ratio, index = [f'PC{i+1}' for i in range(len(ratio))], columns = ['ratio'] )
df_ratio.plot.pie(y='ratio')

# %%
df_ratio
# Out:
#              ratio
# PC1   2.776806e-01
# PC2   2.414216e-01
# PC3   1.397489e-01
# PC4   8.171498e-02
# PC5   7.469264e-02
# PC6   5.531981e-02
# PC7   5.163473e-02
# PC8   3.460381e-02
# PC9   2.333395e-02
# PC10  1.005300e-02
# PC11  5.622225e-03
# PC12  4.173776e-03
# PC13  1.669540e-17
